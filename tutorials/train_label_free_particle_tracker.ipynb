# %%
# %matplotlib inline
import sys
sys.path.append("..")

# %%
import random

import deeptrack as dt
from deeptrack import extras

import numpy as np
import skimage.color
import matplotlib.pyplot as plt


dt.backend.config.disable_gpu()

extras.datasets.load("ParticleTracking")

tracker_input_size = 64

# Can increase to get better validation accuracy at the cost of additional load time
max_frames_to_load = 2500
# Out:
# ParticleTracking already downloaded! Use force_overwrite=True to redownload the dataset.

# %%
import cv2

good_cap = cv2.VideoCapture("./datasets/ParticleTracking/ideal.avi")
bad_cap = cv2.VideoCapture("./datasets/ParticleTracking/bad.avi")

good_frames = []
bad_frames = []


normalization = (
    dt.DummyFeature()
    >> skimage.color.rgb2gray
    >> (lambda i:cv2.resize(i._value, (tracker_input_size, tracker_input_size)))
    >> dt.NormalizeMinMax()
)



idx = 0
while True:
    print(len(good_frames), "      ", end="\r")
    
    ret, frame = good_cap.read()
    if ret and len(good_frames) < max_frames_to_load:
        
        if len(good_frames) == 0:
            orig_size = frame.shape
        
        good_frames.append(normalization(frame))
    else:
        break
        
while True:
    print(len(bad_frames), "      ", end="\r")
    ret, frame = bad_cap.read()
    if ret and len(bad_frames) < max_frames_to_load:
        bad_frames.append(normalization(frame))
        
    else:
        break
        
print(f"Loaded {len(good_frames)} good frames and {len(bad_frames)} noisy frames")
# Out:
# Loaded 2500 good frames and 2500 noisy frames

# %%
tracker_input_size = 64



pipeline = dt.Value(
    use_good=True,
    use_bad=True,
    available_frames=lambda use_good, use_bad: (
        (good_frames if use_good else []) +
        (bad_frames if use_bad else [])
    ),
    value=lambda available_frames: random.choice(available_frames)
) 

print("Low noise frames")
for i in range(4):
    frame = pipeline.update().resolve(use_good=True, use_bad=False)
    
    plt.subplot(2, 2, i + 1)
    plt.imshow(frame, cmap="gray")
    plt.axis("off")
plt.show()
    
print("High noise frames")
for i in range(4):
    frame = pipeline.update().resolve(use_good=False, use_bad=True)
    
    plt.subplot(2, 2, i + 1)
    plt.imshow(frame, cmap="gray")
    plt.axis("off")
plt.show()
# Out:
# Low noise frames
# High noise frames

# %%
input_shape = (tracker_input_size, tracker_input_size, 1)

model_trained_on_low_noise = dt.models.autotrack.AutoTracker(input_shape=input_shape)
model_trained_on_high_noise = dt.models.autotrack.AutoTracker(input_shape=input_shape)
model_trained_on_both = dt.models.autotrack.AutoTracker(input_shape=input_shape)

# %%
h_both = model_trained_on_both.fit(pipeline, batch_size=8, epochs=25)
h_low = model_trained_on_low_noise.fit(dt.Bind(pipeline, use_bad=False), batch_size=8, epochs=25)
h_high = model_trained_on_high_noise.fit(dt.Bind(pipeline, use_good=False), batch_size=8, epochs=25)
# Out:
# Generating 800 / 400 samples before starting training
# Epoch 1/25
# 800/800 [==============================] - 8s 6ms/step - loss: 2.5844
# Epoch 2/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0325
# Epoch 3/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0283
# Epoch 4/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0159
# Epoch 5/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0197
# Epoch 6/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0202
# Epoch 7/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0138
# Epoch 8/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0131
# Epoch 9/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0117
# Epoch 10/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0158
# Epoch 11/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0098
# Epoch 12/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0116
# Epoch 13/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0139
# Epoch 14/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0130
# Epoch 15/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0123
# Epoch 16/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0105
# Epoch 17/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0070
# Epoch 18/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0082
# Epoch 19/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0194
# Epoch 20/25
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0084
# Epoch 21/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0103
# Epoch 22/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0092
# Epoch 23/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0052
# Epoch 24/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0088
# Epoch 25/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0081
# Generating 800 / 400 samples before starting training
# Epoch 1/25
# 800/800 [==============================] - 6s 6ms/step - loss: 2.3790
# Epoch 2/25
# 800/800 [==============================] - 6s 8ms/step - loss: 0.0300
# Epoch 3/25
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0192
# Epoch 4/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0182
# Epoch 5/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0188
# Epoch 6/25
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0141
# Epoch 7/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0265
# Epoch 8/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0148
# Epoch 9/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0212
# Epoch 10/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0104
# Epoch 11/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0066
# Epoch 12/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0113
# Epoch 13/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0105
# Epoch 14/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0144
# Epoch 15/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0039
# Epoch 16/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0184
# Epoch 17/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0034
# Epoch 18/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0124
# Epoch 19/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0094
# Epoch 20/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0097
# Epoch 21/25
# 800/800 [==============================] - 6s 8ms/step - loss: 0.0069
# Epoch 22/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0112
# Epoch 23/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0057
# Epoch 24/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0067
# Epoch 25/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0059
# Generating 800 / 400 samples before starting training
# Epoch 1/25
# 800/800 [==============================] - 6s 6ms/step - loss: 2.4171
# Epoch 2/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0371
# Epoch 3/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0208
# Epoch 4/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0248
# Epoch 5/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0154
# Epoch 6/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0149
# Epoch 7/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0143
# Epoch 8/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0134
# Epoch 9/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0202
# Epoch 10/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0130
# Epoch 11/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0092
# Epoch 12/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0083
# Epoch 13/25
# 800/800 [==============================] - 7s 8ms/step - loss: 0.0087
# Epoch 14/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0114
# Epoch 15/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0086
# Epoch 16/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0105
# Epoch 17/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0101
# Epoch 18/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0109
# Epoch 19/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0054
# Epoch 20/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0069
# Epoch 21/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0125
# Epoch 22/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0115
# Epoch 23/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0064
# Epoch 24/25
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0066
# Epoch 25/25
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0103

# %%
from deeptrack.extras.radialcenter import radialcenter


print("Predicting model_trained_on_both...")
pred_both_good = model_trained_on_both.predict(np.array(good_frames)) 
pred_both_bad = model_trained_on_both.predict(np.array(bad_frames)) 

print("Predicting model_trained_on_low_noise...")
pred_low_good = model_trained_on_low_noise.predict(np.array(good_frames)) 
pred_low_bad = model_trained_on_low_noise.predict(np.array(bad_frames)) 

print("Predicting model_trained_on_high_noise...")
pred_high_good = model_trained_on_high_noise.predict(np.array(good_frames)) 
pred_high_bad = model_trained_on_high_noise.predict(np.array(bad_frames))
print("Predicting using radialcenter...")
pred_radialcenter_good = np.array([radialcenter(f) for f in good_frames])
pred_radialcenter_bad = np.array([radialcenter(f) for f in bad_frames])
# Out:
# Predicting model_trained_on_both...
# Predicting model_trained_on_low_noise...
# Predicting model_trained_on_high_noise...
# Predicting using radialcenter...
# ..\deeptrack\extras\radialcenter.py:91: RuntimeWarning: divide by zero encountered in true_divide
#   m = -(fdv + fdu) / (fdu-fdv);
# ..\deeptrack\extras\radialcenter.py:91: RuntimeWarning: invalid value encountered in true_divide
#   m = -(fdv + fdu) / (fdu-fdv);

# %%
augmentation=dt.Affine(
     translate=lambda: (np.random.rand() - 0.5) * 6,
     scale=lambda: np.random.choice([-1, 1], size=(2,))
 )

# %%
def get_msd(x, max_dt=4):

    output_x = []
    output_y = []
    output_r = []
    for delt in range(max_dt):
        delta = x[1 + delt :] - x[: -(1 + delt)]
        squared_displacement = np.square(delta)
        
        dx = squared_displacement[:, 0]
        dy = squared_displacement[:, 1]
        dr = squared_displacement.sum(axis=-1) / 2
        
        output_x.append(      
            np.mean(dx),
        )
        output_y.append(
            np.mean(dy),
        )
        output_r.append(
            np.mean(dr)
        )
        
    return np.array(output_x), np.array(output_y), np.array(output_r)
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
msd_r_both = get_msd(pred_both_good, 100)[0]
msd_r_low = get_msd(pred_low_good, 100)[0]
msd_r_high = get_msd(pred_high_good, 100)[0]
msd_r_radial = get_msd(pred_radialcenter_good, 100)[1]

tracking_error_both = msd_r_both[0]
tracking_error_low = msd_r_low[0]
tracking_error_high = msd_r_high[0]
tracking_error_radial = msd_r_radial[0]

plt.plot(msd_r_both - tracking_error_both)
plt.plot(msd_r_low - tracking_error_low)
plt.plot(msd_r_high - tracking_error_high)
plt.plot(msd_r_radial - tracking_error_radial)

plt.legend([
    f"Both, pxerr={tracking_error_both:.3f}", 
    f"Low, pxerr={tracking_error_low:.3f}", 
    f"High, pxerr={tracking_error_high:.3f}",
    f"Radialcenter, pxerr={tracking_error_radial:.3f}"
])

plt.subplot(1, 2, 2)
msd_r_both = get_msd(pred_both_bad, 100)[0]
msd_r_low = get_msd(pred_low_bad, 100)[0]
msd_r_high = get_msd(pred_high_bad, 100)[0]
msd_r_radial = get_msd(pred_radialcenter_bad, 100)[1]

tracking_error_both = msd_r_both[0]
tracking_error_low = msd_r_low[0]
tracking_error_high = msd_r_high[0]
tracking_error_radial = msd_r_radial[0]

plt.plot(msd_r_both - tracking_error_both)
plt.plot(msd_r_low - tracking_error_low)
plt.plot(msd_r_high - tracking_error_high)
plt.plot(msd_r_radial - tracking_error_radial)

plt.legend([
    f"Both, pxerr={tracking_error_both:.3f}", 
    f"Low, pxerr={tracking_error_low:.3f}", 
    f"High, pxerr={tracking_error_high:.3f}",
    f"Radialcenter, pxerr={tracking_error_radial:.3f}"
])

plt.show()

# %%
import IPython.display as display

p = pred_both_good - np.mean(pred_both_good, axis=0) + np.mean(pred_radialcenter_good, axis=0)[::-1]
for idx, frame in enumerate(good_frames):
    display.clear_output(wait=True)
    plt.imshow(frame)
    plt.scatter(
        p[idx, 1], 
        p[idx, 0], 
        marker='x'
    )
    plt.scatter(
        pred_radialcenter_good[idx, 0], 
        pred_radialcenter_good[idx, 1], 
        marker='o'
    )
    plt.show()
