# %% [markdown]
# # deeptrack.pytorch.features
#
# <a href="https://colab.research.google.com/github/DeepTrackAI/DeepTrack2/blob/develop/tutorials/3-advanced-topics/DTAT366_pytorch.features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install torch
# !pip install deeptrack  # Uncomment if running on Colab/Kaggle.

# %% [markdown]
# This advanced tutorial introduces the module [deeptrack.pytorch.features](../../deeptrack/pytorch/features.py).

# %%
import numpy as np
import torch

# %% [markdown]
# ## 1. What is `pytorch.features`?
#
# The `pytorch.features` module contains a class `ToTensor` which transforms an input to a PyTorch tensor and lets the user specify the torch.device, expand dimensions, and permute to move the input channel first.

# %% [markdown]
# ## 2. Converting a NumPy Array to a PyTorch Tensor

# %%
from deeptrack.pytorch import ToTensor

numpy_array = np.array([1.0, 2.0, 3.0])

Tensor_converter = ToTensor(
    dtype=torch.float32,
    device=None,
    add_dim_to_number=False,
    permute_mode="numpy",
)

torch_tensor = Tensor_converter(numpy_array)
print(torch_tensor)
# Out:
# tensor([1., 2., 3.])
