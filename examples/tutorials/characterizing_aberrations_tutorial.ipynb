# %%
# %matplotlib inline
# !pip install deeptrack

# %% [markdown]
# <!--<badge>--><a href="https://colab.research.google.com/github/softmatterlab/DeepTrack-2.0/blob/develop/examples/tutorials/characterizing_aberrations_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %% [markdown]
# # DeepTrack 2.0 - Characterizing aberrations
#
# This tutorial demonstrates how to characterize the aberrations of an optical device using the image of a particle. We will specifically look at spherical aberrations, though the example can straightforwardly be extended to other aberrations.
#
# It is recommended to read both [deeptrack_introdution_tutorial](./deeptrack_introdution_tutorial.ipynb) and [tracking_particle_cnn_tutorial](./tracking_particle_cnn_tutorial.ipynb) before reading this tutorial.

# %% [markdown]
# ## 1. Setup
#
# Imports needed for this tutorial.

# %%
import numpy as np
import matplotlib.pyplot as plt

import deeptrack as dt

# %% [markdown]
# ## 2. Define the features
#
# We define the features needed for this example.
#
# * `fluorescence_microscope` - Flourescence microscope with a pixel size of 0.1 microns and a 128x128 camera (see also [optics_example](../module-examples/optics_example.ipynb))
# * `particle` - Spherical particle roughly centered in the image, a micron out of focus (see also [features_example](../module-examples/features_example.ipynb))
# * `aberration` - Spherical aberration with a coefficient between -4 and 4 (see also [aberrations_example](../module-examples/aberrations_example.ipynb))
# * `noise` - A constant background illumantion and a Poisson noise with SNR 100 (see also [noises_example](../module-examples/noises_example.ipynb))
# * `normalization` - Maps the image to values between 0 and 1
#
# In particular, `SphericalAberration` is a wrapper of the more general `Zernike` feature, which introduces a phase to the pupil function based on the normalized Zernike polynomials. The property `coefficient` is a multiplier for the respective poynomial in the set of Zernike polynomials.

# %%
fluorescence_microscope = dt.Fluorescence(
    magnification=10,
    resolution=1e-6,
    wavelength=633e-9,
    output_region=(0, 0, 128, 128)
)

particle = dt.Sphere(
    position=lambda: np.random.randn(3) * (1, 1, 3) + (64, 64, 10),
    position_unit="pixel",
    intensity=10,
    radius=np.random.rand() * 1e-6 + 0.5e-6
)

aberration = dt.SphericalAberration(coefficient=lambda: (2 * np.random.rand() - 1) * 4)

noise = dt.Offset(offset=0.01) >> dt.Poisson(snr=100)

normalization = dt.NormalizeMinMax(min=0, max=1)

# %% [markdown]
# ## 3. Combine the features
#
# To view the particle throught the aberrated microscope, we call `fluorescence_microscope` with both the particle and the aberration. Then we chain the noise and normalization as usual.
#
# By calling `.resolve` with a coefficient, we override the value that the aberration generated for itself. Here we show the aberration at different strengths.

# %%
aberrated_particle = fluorescence_microscope(particle, aberration=aberration) >> noise >> normalization

for coefficient in range(-4, 5):
    aberrated_particle.update(coefficient=coefficient)
    
    plt.title("Spherical aberration of strength {0}".format(coefficient))
    aberrated_particle.plot(cmap="gray")

# %% [markdown]
# ## 4. Define the label function and the generator
#
# We define a label function that iterates through all the properties and returns the coefficient of `SphericalAberration`.

# %%
def get_aberration(image):
    return image.get_property("coefficient")

# %% [markdown]
# We use this function to create a generator of spherically aberrated images of particles to be used to train the neural network model.

# %%
generator = dt.generators.ContinuousGenerator(
    aberrated_particle, 
    get_aberration, 
    batch_size=32,
    min_data_size=1024,
    max_data_size=2048
)

# %% [markdown]
# ## 5. Create the model
#
# We will use the standard convolution model for this task implemented by the function `convolutional` (see also [models_example](../module-examples/models_example.ipynb)). Since this is a regression task, we will use mean absolute error as loss.

# %%
model = dt.models.convolutional(
    input_shape=(128, 128, 1), 
    number_of_outputs=1,
)

# %% [markdown]
# ## 6. Train the model
#
# We train the model for 100 epochs. This will take some time (a few minutes).

# %%
with generator:
    model.fit(generator, epochs=100)
# Out:
# Generating 1025 / 1024 samples before starting training
# Epoch 1/100
# 32/32 [==============================] - 3s 7ms/step - loss: 1.9098
# Epoch 2/100
# 32/32 [==============================] - 0s 7ms/step - loss: 1.8585
# Epoch 3/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.6016
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.5427
# Epoch 5/100
# 32/32 [==============================] - 0s 7ms/step - loss: 1.6642
# Epoch 6/100
# 32/32 [==============================] - 0s 7ms/step - loss: 1.3814
# Epoch 7/100
# 32/32 [==============================] - 0s 7ms/step - loss: 1.3482
# Epoch 8/100
# 32/32 [==============================] - 0s 7ms/step - loss: 1.2357
# Epoch 9/100
# 32/32 [==============================] - 0s 7ms/step - loss: 1.0093
# Epoch 10/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.8504
# Epoch 11/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.8402
# Epoch 12/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.9428
# Epoch 13/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3367
# Epoch 14/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.2399
# Epoch 15/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.2588
# Epoch 16/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2106
# Epoch 17/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1955
# Epoch 18/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1500
# Epoch 19/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1244
# Epoch 20/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1663
# Epoch 21/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1925
# Epoch 22/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1788
# Epoch 23/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1398
# Epoch 24/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.2425
# Epoch 25/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1165
# Epoch 26/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1059
# Epoch 27/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1078
# Epoch 28/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0843
# Epoch 29/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0822
# Epoch 30/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0738
# Epoch 31/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0710
# Epoch 32/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0843
# Epoch 33/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0987
# Epoch 34/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0987
# Epoch 35/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1025
# Epoch 36/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0792
# Epoch 37/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0726
# Epoch 38/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0611
# Epoch 39/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0689
# Epoch 40/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0878
# Epoch 41/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0699
# Epoch 42/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0605
# Epoch 43/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0887
# Epoch 44/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0587
# Epoch 45/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0519
# Epoch 46/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0753
# Epoch 47/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0655
# Epoch 48/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0771
# Epoch 49/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0715
# Epoch 50/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0542
# Epoch 51/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0592
# Epoch 52/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0521
# Epoch 53/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0503
# Epoch 54/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0702
# Epoch 55/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1010
# Epoch 56/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0953
# Epoch 57/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0418
# Epoch 58/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0666
# Epoch 59/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0676
# Epoch 60/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0485
# Epoch 61/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1032
# Epoch 62/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0598
# Epoch 63/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0684
# Epoch 64/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0458
# Epoch 65/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0675
# Epoch 66/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0642
# Epoch 67/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0530
# Epoch 68/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0586
# Epoch 69/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0482
# Epoch 70/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0626
# Epoch 71/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0620
# Epoch 72/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0414
# Epoch 73/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0608
# Epoch 74/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0457
# Epoch 75/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0563
# Epoch 76/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0588
# Epoch 77/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0604
# Epoch 78/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0699
# Epoch 79/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0550
# Epoch 80/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0497
# Epoch 81/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0545
# Epoch 82/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0413
# Epoch 83/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0694
# Epoch 84/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1053
# Epoch 85/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0542
# Epoch 86/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0394
# Epoch 87/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0489
# Epoch 88/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0417
# Epoch 89/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0620
# Epoch 90/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0462
# Epoch 91/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0531
# Epoch 92/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0429
# Epoch 93/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0503
# Epoch 94/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0666
# Epoch 95/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1370
# Epoch 96/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0538
# Epoch 97/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0470
# Epoch 98/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0344
# Epoch 99/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0397
# Epoch 100/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0358

# %% [markdown]
# ## 7. Validate the result
#
# Finally, we validate the result by plotting the predicted value of the spherical aberration against the true value.

# %%
# generator[0] extracts as single batch from the generator
batch, labels = generator[0]

prediction = model.predict(batch)

plt.scatter(labels, prediction)
plt.plot([-5, 5], [-5, 5])
plt.gca().set_aspect('equal', adjustable='box')
plt.xlabel("Ground truth")
plt.ylabel("Predicted value")
plt.title("Spherical aberration coefficient")  
plt.show()
