# %%
# %matplotlib inline
import sys
sys.path.insert(0, "../..")

# %%
import deeptrack as dt
import numpy as np
import skimage.color
import matplotlib.pyplot as plt

# %%
downsample = 2
t, x, y, w = (0, 482, 228, 76)
training_image = dt.LoadImage(f"data/Fluo-C2DL-Huh7/t{t:03d}.tif")()._value / 256
crop = training_image[y:y+w, x:x+w]
plt.imshow(crop, cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 75.5, 75.5, -0.5)

# %%
model = dt.models.AutoMultiTracker(input_shape=(None, None, 1))

train_set =   (
    dt.Value(crop)
    >> dt.Affine(scale=lambda:np.random.uniform(0.7, 1.4, 2), translate=lambda:np.random.uniform(-2, 2, 2))
    >> dt.AveragePooling((downsample, downsample, 1))
    >> dt.Add(lambda: np.random.randn() * 0.2)
    >> dt.Multiply(lambda: np.random.uniform(0.25, 1.1))
    >> dt.Gaussian(sigma=lambda:np.random.uniform(0, 0.04))  
    
)

model.fit(
    train_set,
    epochs=30,
    batch_size=8,
)
# Out:
# Generating 178 / 160 samples before starting training
# Epoch 1/30
# 178/178 [==============================] - 5s 8ms/step - total_loss: 1.9100 - consistency_loss: 0.9903
# Epoch 2/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 2.1999 - consistency_loss: 0.9546
# Epoch 3/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.9070 - consistency_loss: 0.5568
# Epoch 4/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.6990 - consistency_loss: 0.4208
# Epoch 5/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.7145 - consistency_loss: 0.4054
# Epoch 6/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.6790 - consistency_loss: 0.3922
# Epoch 7/30
# 178/178 [==============================] - 2s 9ms/step - total_loss: 0.6380 - consistency_loss: 0.3673
# Epoch 8/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.6679 - consistency_loss: 0.3902
# Epoch 9/30
# 178/178 [==============================] - 2s 12ms/step - total_loss: 0.5823 - consistency_loss: 0.3483
# Epoch 10/30
# 178/178 [==============================] - 2s 12ms/step - total_loss: 0.6045 - consistency_loss: 0.3498
# Epoch 11/30
# 178/178 [==============================] - 2s 12ms/step - total_loss: 0.5899 - consistency_loss: 0.3493
# Epoch 12/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5725 - consistency_loss: 0.3374
# Epoch 13/30
# 178/178 [==============================] - 2s 9ms/step - total_loss: 0.5519 - consistency_loss: 0.3349
# Epoch 14/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5297 - consistency_loss: 0.3140
# Epoch 15/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5327 - consistency_loss: 0.3172
# Epoch 16/30
# 178/178 [==============================] - 2s 12ms/step - total_loss: 0.5625 - consistency_loss: 0.3369
# Epoch 17/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5557 - consistency_loss: 0.3183
# Epoch 18/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5617 - consistency_loss: 0.3316
# Epoch 19/30
# 178/178 [==============================] - 2s 9ms/step - total_loss: 0.5643 - consistency_loss: 0.3166
# Epoch 20/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5494 - consistency_loss: 0.3028
# Epoch 21/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5136 - consistency_loss: 0.2860
# Epoch 22/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5437 - consistency_loss: 0.3070
# Epoch 23/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5767 - consistency_loss: 0.2938
# Epoch 24/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.4718 - consistency_loss: 0.2707
# Epoch 25/30
# 178/178 [==============================] - 2s 9ms/step - total_loss: 0.4928 - consistency_loss: 0.2667
# Epoch 26/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.4787 - consistency_loss: 0.2590
# Epoch 27/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.5016 - consistency_loss: 0.2704
# Epoch 28/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.4417 - consistency_loss: 0.2431
# Epoch 29/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.4391 - consistency_loss: 0.2319
# Epoch 30/30
# 178/178 [==============================] - 2s 11ms/step - total_loss: 0.4701 - consistency_loss: 0.2414

# %%
#May need to tune these to get optimal performance!
alpha = 1
cutoff = 0.97

frame_index = 10

image = (
    dt.LoadImage(f"data/Fluo-C2DL-Huh7/t{frame_index:03d}.tif")
    >> dt.AveragePooling((downsample, downsample, 1))
)()._value / 256


detections = model.predict_and_detect(image[np.newaxis], alpha=alpha, beta=1-alpha, cutoff=cutoff, mode="quantile")[0]
# detections = autotracker.detect(pred[0], weights[0], beta=1-alpha, alpha=alpha, cutoff=cutoff, mode="constant")

plt.figure(figsize=(15, 15))
plt.imshow(image)
plt.axis("off")
plt.scatter(detections[:, 1], detections[:, 0], s=1000, linewidths=4, facecolors="none", edgecolors="r")
