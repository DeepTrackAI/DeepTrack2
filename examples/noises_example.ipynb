# %%
# %matplotlib inline
import sys
sys.path.append("..") # Adds the module to path

# %% [markdown]
# # deeptrack.noises
#
# This notebook introduces the module deeptrack.noises

# %% [markdown]
# ## What is a noise?
#
# Noises are implementations of the abstract class Feature. They differ from other features in that they are not guaranteed to be deterministic. That is, resolving the same feature twice without calling the method `.update()` may result in different images.
#
# Currently the following noises are defined:
#
# * Gaussian noise - adds a Gaussian distributed noise to the image
# * Offset noise - adds a constant offset to the image.
# * Poisson noise - introduces a Poisson distributed noise to the image

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from deeptrack.noises import Gaussian

gaussian_noise = Gaussian(mu=0.1, sigma=0.05)

gaussian_noise.plot()

# %%
from deeptrack.noises import Offset

offset = Offset(offset=0.5)

offset.plot()

# %%
from deeptrack.noises import Poisson

poisson_noise = offset + Poisson(snr=20) 

poisson_noise.plot()
