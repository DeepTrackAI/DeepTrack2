# %% [markdown]
# <!--<badge>--><a href="https://colab.research.google.com/github/softmatterlab/DeepTrack-2.0/blob/bm/readme/examples/paper-examples/1_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %%
# %matplotlib inline

import sys
sys.path.insert(0, "../..")
# %pip install deeptrack==0.6.1

# %% [markdown]
# # Example 1. MNIST
#
# Trains a fully connected neural network to identify handwritten digits using MNIST dataset.

# %% [markdown]
# ## 1. Setup
#
# Imports and defines the objects needed for this example.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import itertools

import deeptrack as dt
from deeptrack.extras import datasets

#Download dataset from the cloud
datasets.load("MNIST")

PATH_TO_DATASET = os.path.abspath("./datasets/MNIST")

TRAINING_SET_PATH = os.path.join(PATH_TO_DATASET, "training_set.npy")
TRAINING_LABELS_PATH = os.path.join(PATH_TO_DATASET, "training_labels.npy")
VALIDATION_SET_PATH = os.path.join(PATH_TO_DATASET, "validation_set.npy")
VALIDATION_LABELS_PATH = os.path.join(PATH_TO_DATASET, "validation_labels.npy")
# Out:
# MNIST already downloaded! Use force_overwrite=True to redownload the dataset.

# %% [markdown]
# ## 2. Defining the dataset
#
# ### 2.1 Loading the data
#
# The dataset is how we provide the network with training data. For this example we create the dataset by loading it from storage using `LoadImage`.

# %%
# Load the images from storage
get_training_images = dt.LoadImage(path=TRAINING_SET_PATH)
get_training_labels = dt.LoadImage(path=TRAINING_LABELS_PATH)

get_validation_images = dt.LoadImage(path=VALIDATION_SET_PATH)
get_validation_labels = dt.LoadImage(path=VALIDATION_LABELS_PATH)

# %% [markdown]
# Note that we don't load the images yet, we have just created the objects that will do so. First we normalize the data.

# %%
normalization = dt.NormalizeMinMax(0, 1)

get_training_images >>= normalization
get_validation_images >>= normalization

# %% [markdown]
# Since all training data is contained in a single file, we explicitly load the images

# %%
training_images = get_training_images.resolve()
training_labels = get_training_labels.resolve()

validation_images = get_validation_images.resolve()
validation_labels = get_validation_labels.resolve()

# %% [markdown]
# We want to continuously generate new data for the network to train on. For this, we use the Dataset feature.

# %%
training_data_iterator = itertools.cycle(training_images)
training_label_iterator = itertools.cycle(training_labels)

training_iterator = dt.Dataset(
    data=training_data_iterator, 
    label=training_label_iterator
)

# %% [markdown]
# ### 2.2 Augmenting the training set
#
# In order to expand the dataset we augment it.

# %% [markdown]
# Affine augmentations consist of translating, rescaling, rotating and shearing

# %%
# How much to scale in x and y
scale = {
    "x": lambda: 0.8 + np.random.rand() * 0.4,
    "y": lambda: 0.8 + np.random.rand() * 0.4
}

# How much to translate in x and y
translate_px = {
    "x": lambda: int(np.random.randint(-2, 3)),
    "y": lambda: int(np.random.randint(-2, 3))
}

# Dummy property: whether to rotate or shear
should_rotate= lambda: np.random.randint(2)

# If should rotate, how much
rotate = lambda should_rotate: (-0.35 + np.random.rand() * 0.7) * should_rotate

# If not should rotate, how much shear
shear = lambda should_rotate: (-0.35 + np.random.rand() * 0.7) * (1 - should_rotate)

affine_transform = dt.Affine(
    scale=scale,
    translate_px=translate_px,
    should_rotate=should_rotate,
    # shear=shear,   
    order=2,
    mode="constant"
)

# %% [markdown]
# We also distort the images elastically.

# %%
elastic_transform = dt.ElasticTransformation(
    alpha=lambda: np.random.rand() * 60, # Amplitude of distortions
    sigma=lambda: 5 + np.random.rand() * 2, # Granularity of distortions
    ignore_last_dim=True, # Last dimension is not a channel, so it should be augmented
    mode="constant"
)

# %% [markdown]
# Finally, since these distortions may cause pixels to fall outside the range of (0, 1), we clip the values.

# %%
clip = dt.Clip(0, 1)

# %% [markdown]
# We add the augmentations to the pipeline

# %%
augmentation = elastic_transform >> affine_transform >> clip
augmented_training_set = training_iterator >> augmentation

# %% [markdown]
# ### 2.3 Defining the target
# The training iterator resolves images. We can extract the label that we provided to the Dataset feature by just calling `get_property`.

# %%
def get_label(image):
    return np.array(image.get_property("label")).squeeze()

# %% [markdown]
# ### 2.3 Visualizing the dataset
#
# To ensure the data and the labels match up we plot 8 images print their correspoding label. To convert the objects we created to an numpy array, we call the method `resolve()`. Since we flattened the images we need to reshape the images again to visualize them.

# %%
NUMBER_OF_IMAGES = 8

for image_index in range(NUMBER_OF_IMAGES):
    
    augmented_training_set.update()
    
    original_image = training_iterator()
    
    
    plt.figure(figsize=(15, 3))
    plt.subplot(1, 6, 1)
    plt.imshow(original_image)
    plt.axis('off')
    plt.title("Original image")
    
    for sub_plt in range(3, 7):
      # Only update the augmentation
      augmentation.update()
      augmented_image = augmented_training_set()
      plt.subplot(1, 6, sub_plt)
      plt.imshow(augmented_image)
      plt.axis('off')
      plt.title("Augmented image")
    
    plt.show()

# %% [markdown]
# ## 3. Defining the network
#
# The network used is a fully connected neural network. Here we define the network architecture, loss function and the optimizer.

# %%
model = dt.models.FullyConnected(
    input_shape=(28, 28, 1),
    dense_layers_dimensions=(500, 500, 500, 500),
    number_of_outputs=10,
    dropout=(0.25, 0.25),
    output_activation="softmax",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
    optimizer="rmsprop"
)

# %% [markdown]
# ## 4. Training the network
#
# The network is trained for 100 epochs using standard Keras syntax.

# %%
TRAIN_MODEL = True

if TRAIN_MODEL:
    generator = dt.generators.ContinuousGenerator(
        augmented_training_set & (augmented_training_set >> get_label),
        batch_size=32,
        min_data_size=1000,
        max_data_size=1001,
    )
    with generator:
        h = model.fit(
            generator,
            validation_data=(np.array(validation_images)[:500],
                            np.array(validation_labels)[:500].squeeze() ),
            epochs=200
        )
    
    plt.plot(h.history["loss"], 'g')
    plt.plot(h.history["val_loss"], 'r')
    plt.legend(["Loss", "Validation loss"])
    plt.yscale("log")
    plt.show()
    
else:
    model_path = datasets.load_model("MNIST")
    model.load_weights(model_path)
# Out:
# Generating 1001 / 1000 samples before starting training
# Epoch 1/200
# 31/31 [==============================] - 6s 112ms/step - loss: 2.2264 - accuracy: 0.1960 - val_loss: 1.3066 - val_accuracy: 0.5700
# Epoch 2/200
# 31/31 [==============================] - 0s 11ms/step - loss: 1.5836 - accuracy: 0.4419 - val_loss: 1.1554 - val_accuracy: 0.5860
# Epoch 3/200
# 31/31 [==============================] - 0s 10ms/step - loss: 1.2559 - accuracy: 0.5748 - val_loss: 0.7458 - val_accuracy: 0.7760
# Epoch 4/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.9358 - accuracy: 0.7141 - val_loss: 0.7008 - val_accuracy: 0.7560
# Epoch 5/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.6798 - accuracy: 0.7529 - val_loss: 0.6132 - val_accuracy: 0.7920
# Epoch 6/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.5385 - accuracy: 0.8064 - val_loss: 0.5124 - val_accuracy: 0.8340
# Epoch 7/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.4502 - accuracy: 0.8472 - val_loss: 0.4449 - val_accuracy: 0.8620
# Epoch 8/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.3015 - accuracy: 0.9133 - val_loss: 0.7323 - val_accuracy: 0.7760
# Epoch 9/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.3214 - accuracy: 0.8961 - val_loss: 0.4258 - val_accuracy: 0.8640
# Epoch 10/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2680 - accuracy: 0.9177 - val_loss: 0.4124 - val_accuracy: 0.8700
# Epoch 11/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.2655 - accuracy: 0.9288 - val_loss: 0.4240 - val_accuracy: 0.8680
# Epoch 12/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2490 - accuracy: 0.9312 - val_loss: 0.4513 - val_accuracy: 0.8760
# Epoch 13/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2120 - accuracy: 0.9531 - val_loss: 0.4771 - val_accuracy: 0.8660
# Epoch 14/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1578 - accuracy: 0.9393 - val_loss: 0.3783 - val_accuracy: 0.8920
# Epoch 15/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1838 - accuracy: 0.9453 - val_loss: 0.5222 - val_accuracy: 0.8540
# Epoch 16/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2178 - accuracy: 0.9435 - val_loss: 0.6483 - val_accuracy: 0.8400
# Epoch 17/200
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1592 - accuracy: 0.9525 - val_loss: 0.4163 - val_accuracy: 0.8840
# Epoch 18/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1322 - accuracy: 0.9643 - val_loss: 0.4888 - val_accuracy: 0.8720
# Epoch 19/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2287 - accuracy: 0.9378 - val_loss: 0.4634 - val_accuracy: 0.8880
# Epoch 20/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2023 - accuracy: 0.9432 - val_loss: 0.4747 - val_accuracy: 0.8740
# Epoch 21/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1604 - accuracy: 0.9525 - val_loss: 0.4954 - val_accuracy: 0.8580
# Epoch 22/200
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2072 - accuracy: 0.9487 - val_loss: 0.2996 - val_accuracy: 0.9120
# Epoch 23/200
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1408 - accuracy: 0.9581 - val_loss: 0.4107 - val_accuracy: 0.9060
# Epoch 24/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1132 - accuracy: 0.9697 - val_loss: 0.5748 - val_accuracy: 0.8620
# Epoch 25/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2390 - accuracy: 0.9358 - val_loss: 0.2792 - val_accuracy: 0.9240
# Epoch 26/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2028 - accuracy: 0.9442 - val_loss: 0.4252 - val_accuracy: 0.9000
# Epoch 27/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1649 - accuracy: 0.9672 - val_loss: 0.6279 - val_accuracy: 0.8780
# Epoch 28/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1745 - accuracy: 0.9580 - val_loss: 0.3071 - val_accuracy: 0.9220
# Epoch 29/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1818 - accuracy: 0.9482 - val_loss: 0.3281 - val_accuracy: 0.9200
# Epoch 30/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2217 - accuracy: 0.9384 - val_loss: 0.4027 - val_accuracy: 0.8980
# Epoch 31/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0875 - accuracy: 0.9763 - val_loss: 0.3900 - val_accuracy: 0.8920
# Epoch 32/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1517 - accuracy: 0.9538 - val_loss: 0.3414 - val_accuracy: 0.9280
# Epoch 33/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1528 - accuracy: 0.9443 - val_loss: 0.5900 - val_accuracy: 0.8680
# Epoch 34/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1533 - accuracy: 0.9720 - val_loss: 0.5237 - val_accuracy: 0.8860
# Epoch 35/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1326 - accuracy: 0.9674 - val_loss: 0.3738 - val_accuracy: 0.9060
# Epoch 36/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1372 - accuracy: 0.9703 - val_loss: 0.5199 - val_accuracy: 0.8600
# Epoch 37/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1726 - accuracy: 0.9542 - val_loss: 0.4392 - val_accuracy: 0.9060
# Epoch 38/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1807 - accuracy: 0.9649 - val_loss: 0.4150 - val_accuracy: 0.9100
# Epoch 39/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1449 - accuracy: 0.9676 - val_loss: 0.4671 - val_accuracy: 0.9060
# Epoch 40/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1747 - accuracy: 0.9501 - val_loss: 0.3815 - val_accuracy: 0.9080
# Epoch 41/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1581 - accuracy: 0.9632 - val_loss: 0.4379 - val_accuracy: 0.8940
# Epoch 42/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1223 - accuracy: 0.9712 - val_loss: 0.4679 - val_accuracy: 0.9080
# Epoch 43/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1399 - accuracy: 0.9706 - val_loss: 0.4660 - val_accuracy: 0.8860
# Epoch 44/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1240 - accuracy: 0.9627 - val_loss: 0.5081 - val_accuracy: 0.9060
# Epoch 45/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1344 - accuracy: 0.9703 - val_loss: 0.3689 - val_accuracy: 0.9100
# Epoch 46/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1363 - accuracy: 0.9593 - val_loss: 0.4634 - val_accuracy: 0.9000
# Epoch 47/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1656 - accuracy: 0.9623 - val_loss: 0.5467 - val_accuracy: 0.8980
# Epoch 48/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 0.9644 - val_loss: 0.5210 - val_accuracy: 0.9100
# Epoch 49/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1591 - accuracy: 0.9690 - val_loss: 0.4042 - val_accuracy: 0.9080
# Epoch 50/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0963 - accuracy: 0.9772 - val_loss: 0.6197 - val_accuracy: 0.9020
# Epoch 51/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1553 - accuracy: 0.9628 - val_loss: 0.6464 - val_accuracy: 0.8780
# Epoch 52/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1610 - accuracy: 0.9570 - val_loss: 0.5047 - val_accuracy: 0.9040
# Epoch 53/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1452 - accuracy: 0.9670 - val_loss: 0.5530 - val_accuracy: 0.9020
# Epoch 54/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1712 - accuracy: 0.9527 - val_loss: 0.4787 - val_accuracy: 0.9060
# Epoch 55/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1401 - accuracy: 0.9648 - val_loss: 0.3841 - val_accuracy: 0.9220
# Epoch 56/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1756 - accuracy: 0.9624 - val_loss: 0.3897 - val_accuracy: 0.9020
# Epoch 57/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1583 - accuracy: 0.9501 - val_loss: 0.4814 - val_accuracy: 0.9060
# Epoch 58/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1582 - accuracy: 0.9588 - val_loss: 0.4897 - val_accuracy: 0.9100
# Epoch 59/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3322 - accuracy: 0.9565 - val_loss: 0.3984 - val_accuracy: 0.9080
# Epoch 60/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1851 - accuracy: 0.9621 - val_loss: 0.3591 - val_accuracy: 0.9100
# Epoch 61/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1038 - accuracy: 0.9777 - val_loss: 0.4147 - val_accuracy: 0.8900
# Epoch 62/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1341 - accuracy: 0.9663 - val_loss: 0.5643 - val_accuracy: 0.8720
# Epoch 63/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1770 - accuracy: 0.9596 - val_loss: 0.3106 - val_accuracy: 0.9260
# Epoch 64/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1447 - accuracy: 0.9619 - val_loss: 0.3816 - val_accuracy: 0.9240
# Epoch 65/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1413 - accuracy: 0.9716 - val_loss: 0.3531 - val_accuracy: 0.9240
# Epoch 66/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1962 - accuracy: 0.9708 - val_loss: 0.4892 - val_accuracy: 0.9020
# Epoch 67/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1643 - accuracy: 0.9674 - val_loss: 0.4167 - val_accuracy: 0.9040
# Epoch 68/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0956 - accuracy: 0.9681 - val_loss: 0.4658 - val_accuracy: 0.8980
# Epoch 69/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1826 - accuracy: 0.9601 - val_loss: 0.4925 - val_accuracy: 0.8960
# Epoch 70/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1302 - accuracy: 0.9631 - val_loss: 0.4398 - val_accuracy: 0.9000
# Epoch 71/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1590 - accuracy: 0.9574 - val_loss: 0.6036 - val_accuracy: 0.8980
# Epoch 72/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1280 - accuracy: 0.9697 - val_loss: 0.5543 - val_accuracy: 0.9060
# Epoch 73/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1627 - accuracy: 0.9561 - val_loss: 0.4217 - val_accuracy: 0.9200
# Epoch 74/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0915 - accuracy: 0.9788 - val_loss: 0.6028 - val_accuracy: 0.8960
# Epoch 75/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2188 - accuracy: 0.9578 - val_loss: 0.4309 - val_accuracy: 0.9100
# Epoch 76/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1762 - accuracy: 0.9665 - val_loss: 0.3224 - val_accuracy: 0.9320
# Epoch 77/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2104 - accuracy: 0.9621 - val_loss: 0.4950 - val_accuracy: 0.9200
# Epoch 78/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1386 - accuracy: 0.9602 - val_loss: 0.6527 - val_accuracy: 0.8960
# Epoch 79/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2022 - accuracy: 0.9453 - val_loss: 0.3835 - val_accuracy: 0.9260
# Epoch 80/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1374 - accuracy: 0.9776 - val_loss: 0.3264 - val_accuracy: 0.9320
# Epoch 81/200
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1682 - accuracy: 0.9726 - val_loss: 0.4263 - val_accuracy: 0.9400
# Epoch 82/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1093 - accuracy: 0.9671 - val_loss: 0.3976 - val_accuracy: 0.9300
# Epoch 83/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0865 - accuracy: 0.9814 - val_loss: 0.3531 - val_accuracy: 0.9480
# Epoch 84/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2182 - accuracy: 0.9532 - val_loss: 0.4085 - val_accuracy: 0.9180
# Epoch 85/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1177 - accuracy: 0.9730 - val_loss: 0.3580 - val_accuracy: 0.9340
# Epoch 86/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1518 - accuracy: 0.9541 - val_loss: 0.3033 - val_accuracy: 0.9300
# Epoch 87/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.2627 - accuracy: 0.9563 - val_loss: 0.4086 - val_accuracy: 0.9260
# Epoch 88/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1694 - accuracy: 0.9725 - val_loss: 0.3702 - val_accuracy: 0.9240
# Epoch 89/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2514 - accuracy: 0.9619 - val_loss: 0.3109 - val_accuracy: 0.9340
# Epoch 90/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2752 - accuracy: 0.9575 - val_loss: 0.3614 - val_accuracy: 0.9300
# Epoch 91/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2069 - accuracy: 0.9561 - val_loss: 0.2353 - val_accuracy: 0.9340
# Epoch 92/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1257 - accuracy: 0.9655 - val_loss: 0.3027 - val_accuracy: 0.9380
# Epoch 93/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2013 - accuracy: 0.9631 - val_loss: 0.4146 - val_accuracy: 0.9240
# Epoch 94/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1847 - accuracy: 0.9548 - val_loss: 0.2610 - val_accuracy: 0.9440
# Epoch 95/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1218 - accuracy: 0.9619 - val_loss: 0.3094 - val_accuracy: 0.9260
# Epoch 96/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1160 - accuracy: 0.9738 - val_loss: 0.2788 - val_accuracy: 0.9380
# Epoch 97/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1306 - accuracy: 0.9709 - val_loss: 0.2309 - val_accuracy: 0.9340
# Epoch 98/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1080 - accuracy: 0.9717 - val_loss: 0.2530 - val_accuracy: 0.9500
# Epoch 99/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1178 - accuracy: 0.9712 - val_loss: 0.2606 - val_accuracy: 0.9440
# Epoch 100/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1416 - accuracy: 0.9727 - val_loss: 0.1946 - val_accuracy: 0.9580
# Epoch 101/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1767 - accuracy: 0.9635 - val_loss: 0.4124 - val_accuracy: 0.9320
# Epoch 102/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1598 - accuracy: 0.9603 - val_loss: 0.2592 - val_accuracy: 0.9500
# Epoch 103/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1655 - accuracy: 0.9563 - val_loss: 0.3486 - val_accuracy: 0.9360
# Epoch 104/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2663 - accuracy: 0.9521 - val_loss: 0.2416 - val_accuracy: 0.9420
# Epoch 105/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1448 - accuracy: 0.9666 - val_loss: 0.2415 - val_accuracy: 0.9560
# Epoch 106/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1087 - accuracy: 0.9697 - val_loss: 0.2299 - val_accuracy: 0.9420
# Epoch 107/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1563 - accuracy: 0.9645 - val_loss: 0.2479 - val_accuracy: 0.9460
# Epoch 108/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1941 - accuracy: 0.9591 - val_loss: 0.3413 - val_accuracy: 0.9140
# Epoch 109/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0850 - accuracy: 0.9698 - val_loss: 0.3426 - val_accuracy: 0.9360
# Epoch 110/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2155 - accuracy: 0.9573 - val_loss: 0.2574 - val_accuracy: 0.9480
# Epoch 111/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2299 - accuracy: 0.9499 - val_loss: 0.2928 - val_accuracy: 0.9480
# Epoch 112/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1868 - accuracy: 0.9646 - val_loss: 0.3981 - val_accuracy: 0.9220
# Epoch 113/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1944 - accuracy: 0.9633 - val_loss: 0.2788 - val_accuracy: 0.9340
# Epoch 114/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1502 - accuracy: 0.9625 - val_loss: 0.3094 - val_accuracy: 0.9340
# Epoch 115/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1845 - accuracy: 0.9502 - val_loss: 0.2944 - val_accuracy: 0.9280
# Epoch 116/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1097 - accuracy: 0.9717 - val_loss: 0.3061 - val_accuracy: 0.9340
# Epoch 117/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1776 - accuracy: 0.9686 - val_loss: 0.3388 - val_accuracy: 0.9280
# Epoch 118/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2054 - accuracy: 0.9645 - val_loss: 0.3367 - val_accuracy: 0.9360
# Epoch 119/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.2109 - accuracy: 0.9688 - val_loss: 0.2571 - val_accuracy: 0.9340
# Epoch 120/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1422 - accuracy: 0.9700 - val_loss: 0.3679 - val_accuracy: 0.9240
# Epoch 121/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0858 - accuracy: 0.9632 - val_loss: 0.4262 - val_accuracy: 0.9300
# Epoch 122/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1740 - accuracy: 0.9672 - val_loss: 0.3388 - val_accuracy: 0.9400
# Epoch 123/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3502 - accuracy: 0.9645 - val_loss: 0.2802 - val_accuracy: 0.9380
# Epoch 124/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0899 - accuracy: 0.9802 - val_loss: 0.3554 - val_accuracy: 0.9380
# Epoch 125/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1156 - accuracy: 0.9763 - val_loss: 0.3305 - val_accuracy: 0.9240
# Epoch 126/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1075 - accuracy: 0.9717 - val_loss: 0.2855 - val_accuracy: 0.9560
# Epoch 127/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0992 - accuracy: 0.9739 - val_loss: 0.3800 - val_accuracy: 0.9300
# Epoch 128/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.2077 - accuracy: 0.9710 - val_loss: 0.4828 - val_accuracy: 0.9140
# Epoch 129/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1415 - accuracy: 0.9714 - val_loss: 0.3431 - val_accuracy: 0.9400
# Epoch 130/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1673 - accuracy: 0.9671 - val_loss: 0.3777 - val_accuracy: 0.9280
# Epoch 131/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1828 - accuracy: 0.9672 - val_loss: 0.3125 - val_accuracy: 0.9240
# Epoch 132/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1374 - accuracy: 0.9693 - val_loss: 0.3124 - val_accuracy: 0.9300
# Epoch 133/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1911 - accuracy: 0.9636 - val_loss: 0.3663 - val_accuracy: 0.9340
# Epoch 134/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1104 - accuracy: 0.9716 - val_loss: 0.3424 - val_accuracy: 0.9420
# Epoch 135/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1454 - accuracy: 0.9663 - val_loss: 0.3932 - val_accuracy: 0.9360
# Epoch 136/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1083 - accuracy: 0.9720 - val_loss: 0.4516 - val_accuracy: 0.9200
# Epoch 137/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1663 - accuracy: 0.9716 - val_loss: 0.4885 - val_accuracy: 0.9220
# Epoch 138/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0884 - accuracy: 0.9789 - val_loss: 0.5108 - val_accuracy: 0.9240
# Epoch 139/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1948 - accuracy: 0.9689 - val_loss: 0.3814 - val_accuracy: 0.9220
# Epoch 140/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1373 - accuracy: 0.9785 - val_loss: 0.4317 - val_accuracy: 0.9240
# Epoch 141/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0961 - accuracy: 0.9744 - val_loss: 0.5377 - val_accuracy: 0.9220
# Epoch 142/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2816 - accuracy: 0.9645 - val_loss: 0.2952 - val_accuracy: 0.9420
# Epoch 143/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2013 - accuracy: 0.9654 - val_loss: 0.5228 - val_accuracy: 0.9260
# Epoch 144/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2147 - accuracy: 0.9547 - val_loss: 0.4469 - val_accuracy: 0.9280
# Epoch 145/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1606 - accuracy: 0.9766 - val_loss: 0.3301 - val_accuracy: 0.9400
# Epoch 146/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1631 - accuracy: 0.9671 - val_loss: 0.5019 - val_accuracy: 0.9360
# Epoch 147/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1599 - accuracy: 0.9760 - val_loss: 0.4133 - val_accuracy: 0.9260
# Epoch 148/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1371 - accuracy: 0.9677 - val_loss: 0.4115 - val_accuracy: 0.9340
# Epoch 149/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1294 - accuracy: 0.9726 - val_loss: 0.4910 - val_accuracy: 0.9280
# Epoch 150/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1214 - accuracy: 0.9777 - val_loss: 0.4323 - val_accuracy: 0.9420
# Epoch 151/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2621 - accuracy: 0.9575 - val_loss: 0.4892 - val_accuracy: 0.9260
# Epoch 152/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1182 - accuracy: 0.9697 - val_loss: 0.4141 - val_accuracy: 0.9340
# Epoch 153/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2607 - accuracy: 0.9608 - val_loss: 0.3736 - val_accuracy: 0.9300
# Epoch 154/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1394 - accuracy: 0.9559 - val_loss: 0.4446 - val_accuracy: 0.9220
# Epoch 155/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1507 - accuracy: 0.9638 - val_loss: 0.3658 - val_accuracy: 0.9420
# Epoch 156/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1363 - accuracy: 0.9645 - val_loss: 0.3552 - val_accuracy: 0.9240
# Epoch 157/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1416 - accuracy: 0.9711 - val_loss: 0.2440 - val_accuracy: 0.9420
# Epoch 158/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.2838 - accuracy: 0.9621 - val_loss: 0.3041 - val_accuracy: 0.9500
# Epoch 159/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1772 - accuracy: 0.9727 - val_loss: 0.3829 - val_accuracy: 0.9360
# Epoch 160/200
# 31/31 [==============================] - 0s 7ms/step - loss: 0.2285 - accuracy: 0.9537 - val_loss: 0.2841 - val_accuracy: 0.9540
# Epoch 161/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1009 - accuracy: 0.9721 - val_loss: 0.4295 - val_accuracy: 0.9420
# Epoch 162/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1442 - accuracy: 0.9643 - val_loss: 0.3171 - val_accuracy: 0.9400
# Epoch 163/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1117 - accuracy: 0.9682 - val_loss: 0.5385 - val_accuracy: 0.9460
# Epoch 164/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1257 - accuracy: 0.9745 - val_loss: 0.3864 - val_accuracy: 0.9400
# Epoch 165/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1389 - accuracy: 0.9742 - val_loss: 0.4518 - val_accuracy: 0.9420
# Epoch 166/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0891 - accuracy: 0.9790 - val_loss: 0.4527 - val_accuracy: 0.9420
# Epoch 167/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1557 - accuracy: 0.9670 - val_loss: 0.3028 - val_accuracy: 0.9520
# Epoch 168/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1217 - accuracy: 0.9684 - val_loss: 0.3132 - val_accuracy: 0.9540
# Epoch 169/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0962 - accuracy: 0.9733 - val_loss: 0.3974 - val_accuracy: 0.9320
# Epoch 170/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1245 - accuracy: 0.9695 - val_loss: 0.3808 - val_accuracy: 0.9380
# Epoch 171/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2036 - accuracy: 0.9577 - val_loss: 0.3226 - val_accuracy: 0.9480
# Epoch 172/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2541 - accuracy: 0.9612 - val_loss: 0.4039 - val_accuracy: 0.9180
# Epoch 173/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1626 - accuracy: 0.9662 - val_loss: 0.3306 - val_accuracy: 0.9440
# Epoch 174/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1201 - accuracy: 0.9754 - val_loss: 0.3274 - val_accuracy: 0.9500
# Epoch 175/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1836 - accuracy: 0.9689 - val_loss: 0.3686 - val_accuracy: 0.9440
# Epoch 176/200
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1929 - accuracy: 0.9765 - val_loss: 0.4313 - val_accuracy: 0.9340
# Epoch 177/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1315 - accuracy: 0.9574 - val_loss: 0.3026 - val_accuracy: 0.9400
# Epoch 178/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1330 - accuracy: 0.9784 - val_loss: 0.4731 - val_accuracy: 0.9360
# Epoch 179/200
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1741 - accuracy: 0.9719 - val_loss: 0.2820 - val_accuracy: 0.9600
# Epoch 180/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1794 - accuracy: 0.9694 - val_loss: 0.3217 - val_accuracy: 0.9320
# Epoch 181/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1130 - accuracy: 0.9725 - val_loss: 0.3442 - val_accuracy: 0.9320
# Epoch 182/200
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1554 - accuracy: 0.9667 - val_loss: 0.3776 - val_accuracy: 0.9360
# Epoch 183/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0871 - accuracy: 0.9816 - val_loss: 0.4145 - val_accuracy: 0.9360
# Epoch 184/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1971 - accuracy: 0.9542 - val_loss: 0.4294 - val_accuracy: 0.9340
# Epoch 185/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2574 - accuracy: 0.9655 - val_loss: 0.3833 - val_accuracy: 0.9420
# Epoch 186/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2187 - accuracy: 0.9641 - val_loss: 0.2642 - val_accuracy: 0.9460
# Epoch 187/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1636 - accuracy: 0.9687 - val_loss: 0.3715 - val_accuracy: 0.9300
# Epoch 188/200
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1604 - accuracy: 0.9747 - val_loss: 0.3224 - val_accuracy: 0.9460
# Epoch 189/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1234 - accuracy: 0.9759 - val_loss: 0.3556 - val_accuracy: 0.9420
# Epoch 190/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1348 - accuracy: 0.9602 - val_loss: 0.4259 - val_accuracy: 0.9380
# Epoch 191/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1752 - accuracy: 0.9601 - val_loss: 0.3055 - val_accuracy: 0.9440
# Epoch 192/200
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1379 - accuracy: 0.9757 - val_loss: 0.2804 - val_accuracy: 0.9540
# Epoch 193/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1939 - accuracy: 0.9674 - val_loss: 0.4226 - val_accuracy: 0.9400
# Epoch 194/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1894 - accuracy: 0.9771 - val_loss: 0.4302 - val_accuracy: 0.9480
# Epoch 195/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1223 - accuracy: 0.9721 - val_loss: 0.3157 - val_accuracy: 0.9440
# Epoch 196/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1180 - accuracy: 0.9676 - val_loss: 0.4622 - val_accuracy: 0.9440
# Epoch 197/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1412 - accuracy: 0.9766 - val_loss: 0.2845 - val_accuracy: 0.9500
# Epoch 198/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1795 - accuracy: 0.9627 - val_loss: 0.2320 - val_accuracy: 0.9560
# Epoch 199/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.2799 - accuracy: 0.9648 - val_loss: 0.1975 - val_accuracy: 0.9480
# Epoch 200/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0788 - accuracy: 0.9780 - val_loss: 0.2961 - val_accuracy: 0.9460

# %% [markdown]
# ## 5. Evaluating the training

# %%
array_of_images = validation_images
array_of_labels = validation_labels

predicted_digits = np.argmax(model.predict(array_of_images), axis=1)

accuracy = np.mean(np.array(array_of_labels) == predicted_digits)
print("Accuracy:", accuracy)
print("Error rate:", 1 - accuracy)
# Out:
# WARNING:tensorflow:Keras is training/fitting/evaluating on array-like data. Keras may not be optimized for this format, so if your input data format is supported by TensorFlow I/O (https://github.com/tensorflow/io) we recommend using that to load a Dataset instead.
# Accuracy: 0.10017754
# Error rate: 0.89982246

# %% [markdown]
# ### 5.1 Prediction vs actual
#
# We show a few images, the true digit and the predicted digit

# %%
NUMBER_OF_IMAGES = 8 
TITLE_STRING = "The image shows the digit {0} \n The model predicted the digit {1}"

for image_index in range(NUMBER_OF_IMAGES):
    image_to_show = np.reshape(array_of_images[image_index], (28, 28))
    plt.imshow(image_to_show)
    plt.title(TITLE_STRING.format(array_of_labels[image_index]._value, predicted_digits[image_index]))
    plt.show()

# %% [markdown]
# ### 5.2 Visualizing errors
#
# We show a few images which the model predicted incorrectly.

# %%
NUMBER_OF_IMAGES = 16

model_is_wrong = predicted_digits != array_of_labels.squeeze()

array_of_hard_images = array_of_images._value[model_is_wrong]
array_of_hard_labels = array_of_labels._value[model_is_wrong]
inaccurately_predicted_digits = predicted_digits[model_is_wrong]

for image_index in range(NUMBER_OF_IMAGES):
    image_to_show = np.reshape(array_of_hard_images[image_index], (28, 28))
    plt.imshow(image_to_show)
    plt.title(TITLE_STRING.format(array_of_hard_labels[image_index], inaccurately_predicted_digits[image_index]))
    plt.show()
