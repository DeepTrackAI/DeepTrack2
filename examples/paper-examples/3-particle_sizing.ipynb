# %%
# %matplotlib inline
# !pip install deeptrack

# %% [markdown]
# <!--<badge>--><a href="https://colab.research.google.com/github/softmatterlab/DeepTrack-2.0/blob/bm/fix-optics-lambda/examples/paper-examples/3-particle_sizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %% [markdown]
# # Example 3. Single particle sizing

# %% [markdown]
# ## 1. Setup
#
# Imports the objects needed for this example.

# %%
import numpy as np
import matplotlib.pyplot as plt

import deeptrack as dt

from deeptrack.extras import datasets
datasets.load('ParticleSizing')
experimental_data = np.load('datasets/ParticleSizing/sizing_150nm_227nm_PSL.npy', allow_pickle=True)

import scipy.io as IO

IMAGE_SIZE = 64
# Out:
# Dataset already downloaded.

# %% [markdown]
# ## 2. Defining the dataset
#
# ### 2.1 Defining the training set
#
# The training set consists of simulated 64 by 64 pixel images, containing a single particle each. The particles are simulated as spheres with a radius between 100nm and 400nm, and a refractive index between 1.37 and 1.67. Its position in the camera plane is constrained to be within within two pixels of the image center, and is sampled with a normal distribution with standard deviation of 2 pixel units along the axis normal to the camera plane.

# %%
particle = dt.MieSphere(
    position=lambda: (IMAGE_SIZE / 2, IMAGE_SIZE / 2) + np.random.rand(2) * 4 - 2,
    z=lambda: np.random.randn() * 2,
    radius=lambda:1e-7 + 3e-7 * np.random.rand() ,
    refractive_index=lambda: np.random.rand() * 0.3 + 1.37,
    L=8,
    position_unit="pixel",
)

# %% [markdown]
# We use a single wavelength brightifeld feature to calculate the field at the camera plane. We aberrate the image with a random coma, which was observed in the experimental data. Moreover, the pupil is cropped at high frequencies.

# %%
HC = dt.HorizontalComa(coefficient=lambda c1: c1, c1=0 + np.random.randn() * 0.5)
VC = dt.VerticalComa(coefficient=lambda c2:c2, c2=0 + np.random.randn() * 0.5)

def crop(pupil_radius):
    def inner(image):
        x = np.arange(image.shape[0]) - image.shape[0] / 2
        y = np.arange(image.shape[1]) - image.shape[1] / 2
        X, Y = np.meshgrid(x, y)
        image[X ** 2 + Y ** 2 > pupil_radius ** 2] = 0
        return image
    return inner
CROP = dt.Lambda(crop, pupil_radius=23)

optics = dt.Brightfield(
    NA=1.3,
    resolution=1.13e-6,
    wavelength=635e-9,
    aperature_angle=53.7 * 2 * np.pi / 360,
    polarization_angle=lambda: np.random.rand() * 2 * np.pi,
    magnification=10,
    output_region=(0, 0, IMAGE_SIZE, IMAGE_SIZE),
    padding=(64,) * 4,
    return_field=True,
    pupil= HC >> VC >> CROP
)

# %% [markdown]
# The noise is simulated as gaussian distributed noise, with independent real and imaginary parts. The amplitude of the noise is determined by the dummy property `level`, which is explicitly shared between the two features. Finally, the real and imaginary parts of the field are separated into two layers, and the plane wave is subtracted.

# %%
real_noise = dt.Gaussian(
    mu=0, 
    sigma=lambda: np.random.rand() * 0.02,
)

noise = real_noise >> dt.Gaussian(
    mu=0, 
    sigma=lambda real_sigma: real_sigma * 0.03j,
    real_sigma=real_noise.sigma
)

def func():
    def inner(image):
        image = image - 1
        output = np.zeros((*image.shape[:2], 2))
        output[..., 0:1] = np.real(image)
        output[..., 1:2] = np.imag(image)
        return output
    return inner


complex_to_float = dt.Lambda(func)

# %% [markdown]
# We now define how these objects combine. Note that the noise is added inside the optics. This means that it will have the same PSF as the sample, which is what is observed.

# %%
dataset = optics(particle >> noise) >> complex_to_float

# %% [markdown]
# ### 2.2 Defining the training label
#
# We extract the parameters we want the network to learn. We also rescale them such that they have a similar size.

# %%
def get_label(image):
    px = np.array(image.get_property("position")) - IMAGE_SIZE / 2
    z = image.get_property("z") * 0.1
    r = image.get_property("radius") / 1e-6
    n = image.get_property("refractive_index") - 1.33
    return np.array([r * 10, n * 10])

# %% [markdown]
# # 2.3 Visualizing the dataset
#
# We resolve and show 16 images

# %%
## NUMBER_OF_IMAGES = 16

for i in range(8):
    dataset.update()
    image_of_particle = dataset.resolve()

    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    plt.imshow(image_of_particle[:, :, 0], cmap="gray")
    plt.colorbar()
    
    plt.subplot(1,2,2)
    plt.imshow(image_of_particle[:, :, 1], cmap="gray")
    plt.colorbar()
    plt.show()

# %% [markdown]
# ## 3. Defining the network
#
# The network used is a Convolutional network, with a the pixel error as loss.

# %%
import tensorflow.keras.backend as K
import tensorflow.keras.optimizers as optimizers

model = dt.models.Convolutional(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 2),
    conv_layers_dimensions=(32, 64, 128),
    dense_layers_dimensions=(64, 64),
    steps_per_pooling=2,
    number_of_outputs=2,
    dropout=(.2, .2),
    loss="mae",
    optimizer="adam",
    dense_block=dt.layers.DenseBlock(activation="relu")
)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 2)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 32)        608
# _________________________________________________________________
# activation_8 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# activation_9 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_10 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_11 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                524352
# _________________________________________________________________
# activation_14 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_15 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 815,362
# Trainable params: 815,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4. Training the network

# %% [markdown]
# We use the `ContinuousGenerator` to generate the images. It creates a new thread and generates images while the model is training.
#
# Set TRAIN_MODEL to True to train the model, otherwise a pretrained model is downloaded.

# %%
TRAIN_MODEL = True

validation_set_size = 256
validation_set = [dataset.update().resolve() for _ in range(validation_set_size)]
validation_labels = [get_label(image) for image in validation_set]

if TRAIN_MODEL:
    generator = dt.generators.ContinuousGenerator(
        dataset & (dataset >> get_label),
        min_data_size=int(2e3),
        max_data_size=int(2e4),
        batch_size=64,
        max_epochs_per_sample=33
    )

    with generator:
        h = model.fit(
            generator,
            validation_data=(
                np.array(validation_set), 
                np.array(validation_labels)
            ),
            epochs=100,
        )
    
    plt.plot(h.history["val_loss"])
    
else:
    model_path = datasets.load_model("ParticleSizing")
    model.load_weights(model_path)
# Out:
# Generating 2004 / 2000 samples before starting training
# Epoch 1/100
# 31/31 [==============================] - 2s 24ms/step - loss: 1.5974 - val_loss: 0.5584
# Epoch 2/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.6171 - val_loss: 0.5092
# Epoch 3/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5565 - val_loss: 0.4769
# Epoch 4/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5409 - val_loss: 0.4924
# Epoch 5/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5304 - val_loss: 0.4948
# Epoch 6/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5154 - val_loss: 0.4483
# Epoch 7/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.4972 - val_loss: 0.4064
# Epoch 8/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.4407 - val_loss: 0.3965
# Epoch 9/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.4242 - val_loss: 0.3812
# Epoch 10/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.3846 - val_loss: 0.2948
# Epoch 11/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.3655 - val_loss: 0.3361
# Epoch 12/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.3137 - val_loss: 0.3811
# Epoch 13/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3074 - val_loss: 0.3504
# Epoch 14/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3008 - val_loss: 0.3270
# Epoch 15/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2720 - val_loss: 0.2714
# Epoch 16/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2610 - val_loss: 0.3618
# Epoch 17/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2715 - val_loss: 0.3230
# Epoch 18/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2653 - val_loss: 0.3395
# Epoch 19/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2344 - val_loss: 0.3559
# Epoch 20/100
# 31/31 [==============================] - 1s 26ms/step - loss: 0.2495 - val_loss: 0.3094
# Epoch 21/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3011 - val_loss: 0.3671
# Epoch 22/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2893 - val_loss: 0.2771
# Epoch 23/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2480 - val_loss: 0.3280
# Epoch 24/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2300 - val_loss: 0.2787
# Epoch 25/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2372 - val_loss: 0.3930
# Epoch 26/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2288 - val_loss: 0.3588
# Epoch 27/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2229 - val_loss: 0.3298
# Epoch 28/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2172 - val_loss: 0.2952
# Epoch 29/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.2107 - val_loss: 0.3043
# Epoch 30/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2011 - val_loss: 0.3222
# Epoch 31/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2121 - val_loss: 0.2884
# Epoch 32/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1988 - val_loss: 0.2880
# Epoch 33/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2042 - val_loss: 0.3450
# Epoch 34/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1934 - val_loss: 0.3049
# Epoch 35/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2014 - val_loss: 0.2883
# Epoch 36/100dataset to reach minimum size: 1998 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1845 - val_loss: 0.2827
# Epoch 37/100dataset to reach minimum size: 1997 / 2000
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2110 - val_loss: 0.3389
# Epoch 38/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2210 - val_loss: 0.3237
# Epoch 39/100dataset to reach minimum size: 1997 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2134 - val_loss: 0.3299
# Epoch 40/100dataset to reach minimum size: 1998 / 2000
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2081 - val_loss: 0.2899
# Epoch 41/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1997 - val_loss: 0.3387
# Epoch 42/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1851 - val_loss: 0.3282
# Epoch 43/100dataset to reach minimum size: 1997 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1937 - val_loss: 0.2918
# Epoch 44/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2198 - val_loss: 0.2619
# Epoch 45/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1894 - val_loss: 0.3078
# Epoch 46/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1784 - val_loss: 0.3102
# Epoch 47/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1925 - val_loss: 0.3502
# Epoch 48/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1999 - val_loss: 0.3204
# Epoch 49/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1787 - val_loss: 0.2802
# Epoch 50/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1932 - val_loss: 0.2983
# Epoch 51/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1874 - val_loss: 0.2949
# Epoch 52/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1975 - val_loss: 0.3622
# Epoch 53/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1819 - val_loss: 0.2934
# Epoch 54/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1875 - val_loss: 0.3192
# Epoch 55/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1751 - val_loss: 0.2810
# Epoch 56/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1728 - val_loss: 0.2686
# Epoch 57/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1721 - val_loss: 0.2945
# Epoch 58/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1647 - val_loss: 0.2771
# Epoch 59/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1831 - val_loss: 0.2802
# Epoch 60/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1748 - val_loss: 0.2755
# Epoch 61/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1675 - val_loss: 0.3631
# Epoch 62/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1902 - val_loss: 0.2889
# Epoch 63/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1841 - val_loss: 0.2706
# Epoch 64/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1832 - val_loss: 0.2923
# Epoch 65/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1759 - val_loss: 0.3273
# Epoch 66/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1786 - val_loss: 0.2891
# Epoch 67/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1598 - val_loss: 0.2697
# Epoch 68/100dataset to reach minimum size: 1998 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1695 - val_loss: 0.2572
# Epoch 69/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1873 - val_loss: 0.2737
# Epoch 70/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1677 - val_loss: 0.3274
# Epoch 71/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 15ms/step - loss: 0.1766 - val_loss: 0.2838
# Epoch 72/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1671 - val_loss: 0.2535
# Epoch 73/100dataset to reach minimum size: 1997 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1704 - val_loss: 0.2548
# Epoch 74/100dataset to reach minimum size: 1998 / 2000
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1743 - val_loss: 0.2577
# Epoch 75/100dataset to reach minimum size: 1996 / 2000
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1690 - val_loss: 0.3019
# Epoch 76/100dataset to reach minimum size: 1996 / 2000
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1736 - val_loss: 0.2791
# Epoch 77/100dataset to reach minimum size: 1997 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1585 - val_loss: 0.2843
# Epoch 78/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1691 - val_loss: 0.3005
# Epoch 79/100dataset to reach minimum size: 1998 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1571 - val_loss: 0.2816
# Epoch 80/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1522 - val_loss: 0.2620
# Epoch 81/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1559 - val_loss: 0.2792
# Epoch 82/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1494 - val_loss: 0.2860
# Epoch 83/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1545 - val_loss: 0.2903
# Epoch 84/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1485 - val_loss: 0.3001
# Epoch 85/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1512 - val_loss: 0.2729
# Epoch 86/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1505 - val_loss: 0.2744
# Epoch 87/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1566 - val_loss: 0.2921
# Epoch 88/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1590 - val_loss: 0.2686
# Epoch 89/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1564 - val_loss: 0.2749
# Epoch 90/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1613 - val_loss: 0.2559
# Epoch 91/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1443 - val_loss: 0.2963
# Epoch 92/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1354 - val_loss: 0.2966
# Epoch 93/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1357 - val_loss: 0.2817
# Epoch 94/100dataset to reach minimum size: 1997 / 2000
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1437 - val_loss: 0.3172
# Epoch 95/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1534 - val_loss: 0.2975
# Epoch 96/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1397 - val_loss: 0.2684
# Epoch 97/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1315 - val_loss: 0.2790
# Epoch 98/100dataset to reach minimum size: 1999 / 2000
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1339 - val_loss: 0.2898
# Epoch 99/100dataset to reach minimum size: 1998 / 2000
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1542 - val_loss: 0.2993
# Epoch 100/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1489 - val_loss: 0.2464

# %% [markdown]
# ## 5. Evaluating the network
#
# We show the the error as a function of some properties.

# %%
properties = ["radius", "refractive_index", "sigma"]

validation_prediction = model.predict(np.array(validation_set))

validation_errors = [
    np.abs(validation_prediction[:, idx] - np.array(validation_labels)[:, idx]) for idx in range(2)
]

error_names = ["radius", "refractive index"]

for property_name in properties:
    property_values = np.array([image.get_property(property_name) for image in validation_set])
    if property_values.ndim == 1:
        property_values = np.expand_dims(property_values, axis=-1)
    
    for col in range(property_values.shape[1]):
        values = property_values[:, col]

        plt.subplot(1, property_values.shape[1], col + 1)
        for validation_error in validation_errors:
            plt.scatter(values, validation_error, alpha=1)
        plt.xlim([np.min(values), np.max(values)])
        plt.ylim([np.min(validation_error), np.max(validation_error)])
        plt.yscale("log")
        plt.ylabel("Absolute error")
        plt.xlabel("{0}[{1}]".format(property_name, col))
        
    plt.legend(error_names)

    
    plt.show()

# %% [markdown]
# We estimate the size of particles using experimentally captured images. The particles were traced, so we display the average size and refractive index measured by the model over the trace.

# %%
predictions = np.array([
        np.mean(
            model.predict(
                np.array(experimental_data[idx])
            ),
            axis=0
        ) for idx in range(len(experimental_data))
])

print(np.mean(predictions))
plt.scatter([],[], c='b', alpha=1)
plt.scatter(0.227 * 1000, 1.58, marker='x', s=200, c='r')
plt.scatter(0.15 * 1000, 1.58, marker='x', s=200, c='g')

plt.scatter(predictions[:, 0] * 100, predictions[:, 1] / 10 + 1.33, c='m', alpha=0.1)
plt.scatter(0.227 * 1000, 1.58, marker='x', s=200, c='r')
plt.scatter(0.15 * 1000, 1.58, marker='x', s=200, c='g')


plt.legend(["Model prediction", "150nm PSL", "227nm PSL"])
# plt.axis([100, 300, 1.4, 1.7])
plt.xlabel('Radius (nm)')
plt.ylabel('Refractive index')
plt.show()
# Out:
# 2.2323873
